# %% [markdown]
# ### 1d_axial_big.ipynb
# #### This is a notebook containing an example of a long 1D axial range expansion.
# ---
# First, include the 1d.jl script to use its functions:

# %%
include("../1d.jl")
# Out:
# 2d.jl successfully loaded.

# %% [markdown]
# For a simpler calculation, it is sometimes viable to simulate a range expansion using the infinite sites model. Simply use the suffix *_inf* for infinite-sites simulations:

# %%
test = rangeexp_axial_inf(100,1000;data_to_generate="FPSN",prop_of_sel_loci=0.8,y_max=8,migr_mode="diag1/2")
# Out:
# Dict{String, Any} with 7 entries:
#   "pops"   => Float32[21.0 18.0 … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN…
#   "meanf"  => Float32[1.0 1.0 … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN N…
#   "delneu" => Float32[4.0 3.0 … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN N…
#   "bensel" => Float32[3.0 3.0 … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN N…
#   "delsel" => Float32[14.0 8.0 … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN …
#   "benneu" => Float32[2.0 0.0 … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN N…
#   "stats"  => Dict{String, Any}("y_max_burnin"=>10, "x_max"=>100, "r_prolif_rat…

# %% [markdown]
# It is much faster, although it ignores the biallelic structure, hence there is no dominance coefficient. Instead of *n_loci*, it has *n_segr_regions*; and instead of *n_sel_loci*, it has *prop_of_sel_loci*:

# %%
re_heatmap_pops(test;slow_factor=0.2)

# %%
re_heatmap_bensel(test;slow_factor=0.2)

# %%
re_heatmap_meanf(test;slow_factor=0.333)

# %% [markdown]
# Notice how the fitness distribution gets higher (brighter) overall, after the whole space has been filled and the expansion is essentially stopped.
#
# This can be confirmed with the mean fitness graphs:

# %%
test_meanf_frontav = average_front(test,"meanf")
plot(test_meanf_frontav,xlabel="Generation",label="Mean front fitness")

# %%
test_meanf_av = average_all(test,"meanf")
plot(test_meanf_av,xlabel="Generation",label="Mean front fitness")

# %% [markdown]
# The front array stays at the end after the space has been filled:

# %%
test_meanf_frontarr = front_array(test,"meanf";oneside=true)
re_heatmap_meanf(test_meanf_frontarr,500,600)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_sfGPEDyLU7.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_sfGPEDyLU7.gif")
