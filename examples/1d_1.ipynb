# %% [markdown]
# ### 1d_1.ipynb
# #### This is a notebook containing an example of a 1D one-way range expansion.
# ---
# First, include the RESK library:

# %%
include("../resk.jl")
# Out:
# RESK successfully loaded.

# %% [markdown]
# For a simpler calculation, it is sometimes viable to simulate a range expansion using the infinite sites model. Simply use the suffix *_inf* for infinite-sites simulations:

# %%
test = rangeexp_1d(;data_to_generate="FPSN")
# Out:
# Dict{String, Any} with 9 entries:
#   "AAsel" => Float32[0.0 0.0 … 5.04762 2.66667; 0.0 0.0 … 5.80952 3.90909; … ; …
#   "pops"  => Float32[20.0 15.0 … 12.0 12.0; 19.0 22.0 … 11.0 7.0; … ; NaN NaN ……
#   "aasel" => Float32[500.0 499.75 … 481.0 481.083; 500.0 499.762 … 480.19 479.9…
#   "fitn"  => Float32[1.0 1.0 … 0.989977 0.994699; 1.0 1.0 … 0.98848 0.992229; ……
#   "aaneu" => Float32[500.0 499.55 … 486.238 485.417; 500.0 499.524 … 487.762 48…
#   "Aasel" => Float32[0.0 0.25 … 13.9524 16.25; 0.0 0.238095 … 14.0 16.1818; … ;…
#   "Aaneu" => Float32[0.0 0.45 … 10.0952 11.8333; 0.0 0.47619 … 8.66667 11.5455;…
#   "AAneu" => Float32[0.0 0.0 … 3.66667 2.75; 0.0 0.0 … 3.57143 2.18182; … ; NaN…
#   "stats" => Dict{String, Any}("capacity"=>20, "wlddim"=>1, "max_burnin"=>(5,),…

# %%
repl(test["fitn"],1)
# Out:
# 100×50 Matrix{Float32}:
#    1.0    1.0    1.0         0.9999  …    0.986674    0.989977    0.994699
#    1.0    1.0    1.0         1.0          0.992649    0.98848     0.992229
#    1.0    1.0    1.0         1.0          0.990491    0.990859    0.990834
#    1.0    1.0    1.0         1.0          0.995353    0.992786    0.991218
#    1.0    1.0    0.999857    1.0          0.996908    0.995699    0.995387
#  NaN    NaN    NaN         NaN       …    0.994177    0.995183    0.995074
#  NaN    NaN    NaN         NaN            0.99409     0.993613    0.994384
#  NaN    NaN    NaN         NaN            0.995413    0.993898    0.993424
#  NaN    NaN    NaN         NaN            0.996008    0.992627    0.992606
#  NaN    NaN    NaN         NaN            0.992736    0.99277     0.991585
#    ⋮                                 ⋱
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN
#  NaN    NaN    NaN         NaN       …  NaN         NaN         NaN
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN
#  NaN    NaN    NaN         NaN          NaN         NaN         NaN

# %%
test["pops"]
# Out:
# 100×50×1 Array{Float32, 3}:
# [:, :, 1] =
#   12.0   13.0   10.0   12.0   11.0  …   29.0   16.0   19.0   15.0   19.0
#   19.0   19.0   21.0   21.0   18.0      23.0   17.0   14.0   20.0   20.0
#   21.0   17.0   21.0   20.0   19.0      16.0   25.0   26.0   22.0   14.0
#   22.0   19.0   16.0   19.0   14.0      19.0   16.0   30.0   16.0   24.0
#   26.0   20.0   23.0   29.0   23.0      32.0   32.0   17.0   23.0   24.0
#  NaN    NaN    NaN    NaN    NaN    …   26.0   21.0   37.0   22.0   17.0
#  NaN    NaN    NaN    NaN    NaN        17.0   30.0   25.0   24.0   20.0
#  NaN    NaN    NaN    NaN    NaN        24.0   28.0   20.0   12.0   14.0
#  NaN    NaN    NaN    NaN    NaN        21.0   16.0   13.0   13.0   17.0
#  NaN    NaN    NaN    NaN    NaN        27.0   26.0   24.0   23.0   16.0
#    ⋮                                ⋱    ⋮
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN    …  NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN
#  NaN    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN

# %% [markdown]
# It is much faster, although it ignores the biallelic structure, hence there is no dominance coefficient. Instead of *n_loci*, it has *n_segr_regions*; and instead of *n_sel_loci*, it has *prop_of_sel_loci*:

# %%
test["stats"]
# Out:
# Dict{String, Any} with 21 entries:
#   "wlddim"            => 1
#   "r_prolif_rate"     => 1.8
#   "max_burnin"        => (5,)
#   "name"              => "2024-07-11_09-21-51"
#   "startfill"         => UnitRange{Int64}[1:5]
#   "s_sel_coef"        => 0.002
#   "n_gens_burnin"     => 30
#   "k_capacity"        => 20
#   "prop_of_del_muts"  => 0.9
#   "migr_rate"         => 0.1
#   "sel_loci"          => [223, 425, 590, 890, 500, 550, 343, 429, 260, 76  …  3…
#   "max"               => (100,)
#   "n_gens"            => 130
#   "migr_mode"         => "ort"
#   "n_gens_exp"        => 100
#   "mut_rate"          => 0.7567
#   "h_domin_coef"      => 0
#   "n_loci"            => 1000
#   "max_exp"           => (100,)
#   ⋮                   => ⋮

# %%
re_heatmap(test["pops"][:,:,1],1,1,50;n_gens_sub=10)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_78xmTAtcTE.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_78xmTAtcTE.gif")

# %% [markdown]
# The colour maximum for this graph was determined automatically, but 40 is actually twice the capacity, and while single demes' populations sometimes exceed the capacity, it might be easier to look at the graph where the maximum is the capacity. For this, we have a special function:

# %%
re_heatmap_pops(test)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_wP8NALeRGl.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_wP8NALeRGl.gif")

# %%
re_heatmap_aasel(test)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_x2XItOfUfq.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_x2XItOfUfq.gif")

# %%
re_heatmap_aasel(test;clim=(450,550),slow_factor=0.5)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_1aDGvy7E7g.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_1aDGvy7E7g.gif")

# %%
re_heatmap_fitn(test;clim=(0.9,1.0))
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_nwxY7E5sLQ.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_nwxY7E5sLQ.gif")

# %% [markdown]
# Notice how the fitness distribution gets higher (brighter) overall, after the whole space has been filled and the expansion is essentially stopped.
#
# This can be confirmed with the mean fitness graphs:

# %%
re_heatmap(test,"fitn")
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_pmrcFchYHS.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_pmrcFchYHS.gif")

# %%
test_fitn_frontarr = front_array(test,"fitn";oneside=true)
re_heatmap(test_fitn_frontarr,2,1,100)
# Out:
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_l6HiLAFUns.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_l6HiLAFUns.gif")

# %%
test_fitn_frontav = average_front(test,"fitn")
Plots.plot(test_fitn_frontav,xlabel="Generation",label="Mean front fitness")

# %%
test_fitn_av = average_all(test,"fitn")
Plots.plot(test_fitn_av,xlabel="Generation",label="Mean front fitness")
