# %% [markdown]
# ### 1d_2.ipynb
# #### Additional examples of 1D range expansions.
# ---
# Include RESK and RESKPlots:

# %%
include("../resk.jl")
include("../reskplots.jl")
# Out:
# RESK successfully loaded.
# RESKPlots successfully loaded.

# %% [markdown]
# Let us try out the hexagon expansions:

# %%
test = rangeexp_strip(60,60;data_to_generate="FPSN",migr_mode="hex",x_max_burnin=3, x_max_exp=32, y_max=5,mut_rate=0.5)
# Out:
# Dict{String, Any} with 9 entries:
#   "AAsel" => Float32[0.0 0.0 … NaN 0.0; NaN 0.0 … NaN NaN; … ; NaN NaN … NaN Na…
#   "pops"  => Float32[16.0 27.0 … NaN 14.0; NaN 23.0 … NaN NaN; … ; NaN NaN … Na…
#   "aasel" => Float32[500.0 500.0 … NaN 500.0; NaN 500.0 … NaN NaN; … ; NaN NaN …
#   "fitn"  => Float32[1.0 1.0 … NaN 1.0; NaN 1.0 … NaN NaN; … ; NaN NaN … NaN Na…
#   "aaneu" => Float32[500.0 500.0 … NaN 500.0; NaN 500.0 … NaN NaN; … ; NaN NaN …
#   "Aasel" => Float32[0.0 0.0 … NaN 0.0; NaN 0.0 … NaN NaN; … ; NaN NaN … NaN Na…
#   "Aaneu" => Float32[0.0 0.0 … NaN 0.0; NaN 0.0 … NaN NaN; … ; NaN NaN … NaN Na…
#   "AAneu" => Float32[0.0 0.0 … NaN 0.0; NaN 0.0 … NaN NaN; … ; NaN NaN … NaN Na…
#   "stats" => Dict{String, Any}("capacity"=>20, "wlddim"=>2, "max_burnin"=>(3, 5…

# %%
re_heatmap(test,"pops")
# Out:
# (1.0f0, 42.0f0)
# ┌ Info: Frames for animation "test.gif" are being stored in directory:
# │ 	 C:\Users\Hartree\AppData\Local\Temp\jl_qYOX2F
# └ @ Luxor C:\Users\Hartree\.julia\packages\Luxor\0kqwd\src\animate.jl:199
# ┌ Info: ... 120 frames saved in directory:
# │ 	 C:\Users\Hartree\AppData\Local\Temp\jl_qYOX2F
# └ @ Luxor C:\Users\Hartree\.julia\packages\Luxor\0kqwd\src\animate.jl:221
# ┌ Info: GIF is: C:\Users\Hartree\AppData\Local\Temp\jl_qYOX2F/test.gif.gif
# └ @ Luxor C:\Users\Hartree\.julia\packages\Luxor\0kqwd\src\animate.jl:266
# Luxor.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_qYOX2F/test.gif.gif")

# %%
re_heatmap(test,"fitn")
# Out:
# (0.9561946f0, 1.0f0)
# ┌ Info: Frames for animation "test.gif" are being stored in directory:
# │ 	 C:\Users\Hartree\AppData\Local\Temp\jl_7QiKKm
# └ @ Luxor C:\Users\Hartree\.julia\packages\Luxor\0kqwd\src\animate.jl:199
# ┌ Info: ... 120 frames saved in directory:
# │ 	 C:\Users\Hartree\AppData\Local\Temp\jl_7QiKKm
# └ @ Luxor C:\Users\Hartree\.julia\packages\Luxor\0kqwd\src\animate.jl:221
# ┌ Info: GIF is: C:\Users\Hartree\AppData\Local\Temp\jl_7QiKKm/test.gif.gif
# └ @ Luxor C:\Users\Hartree\.julia\packages\Luxor\0kqwd\src\animate.jl:266
# Luxor.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_7QiKKm/test.gif.gif")
