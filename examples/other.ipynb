# %%
include("../resk.jl")
# Out:
# RESK successfully loaded.

# %%
world, world_stats = create_empty_world_inf()
fill_random_demes_inf(world,world_stats,100,5,300)
# Out:
# 300

# %%
heatmap(.!isempty.(world))
