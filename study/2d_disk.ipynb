# %%
include("../resk.jl")
include("../reskplots.jl")
# Out:
# RESK successfully loaded.
# RESKPlots successfully loaded.

# %% [markdown]
# ---

# %%
@everywhere include("resk.jl")

A = rangeexp_disk(100,250,20;r_max_burnin=3,r_max_exp=70,data_to_generate="FlAlPl",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
weightfitn=false,condsel=true,fixed_mate=true,SS=true,prop_of_del_muts=0.9)

# %%
re_heatmap(twoDD,"fitn",350,350)
# Out:
# 3
# (0.960693f0, 1.0108972f0)
# ┌ Info: Saved animation to C:\Users\LOCAL_~1\AppData\Local\Temp\jl_GNih23arUf.gif
# └ @ Plots C:\Users\local_axjynym\.julia\packages\Plots\Ec1L1\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\LOCAL_~1\\AppData\\Local\\Temp\\jl_GNih23arUf.gif")

# %%
re_heatmap(average_all(twoDD)[:,:,100:end],250;animspeed=2)
# Out:
# Plots.AnimatedGif("C:\\Users\\LOCAL_~1\\AppData\\Local\\Temp\\jl_GhmzOdCRWL.gif")
