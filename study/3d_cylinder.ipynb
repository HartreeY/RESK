# %%
include("../resk.jl")
include("../reskplots.jl")
# Out:
# RESK successfully loaded.
# RESKPlots successfully loaded.

# %% [markdown]
# ---

# %%
@everywhere include("resk.jl")

threeDC = rangeexp_cylinder(100,250,20;z_max_burnin=3,z_max_exp=50,r_max=5,data_to_generate="FlAlPl",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
weightfitn=false,condsel=true,fixed_mate=true,SS=true,prop_of_del_muts=0.9)
# Out:
# max_burnin (NaN, NaN, 3)
# startfill_range UnitRange{Int64}[3:9, 3:9, 1:3]
# startfill_iter nothing
# Simulated in 104.2116854 s.
# OrderedDict{String, Any} with 2 entries:
#   "stats" => OrderedDict{String, Any}("name"=>"2025-09-09_23-03-52", "max"=>(11…
#   "fitn"  => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…

# %%
re_heatstack(threeDC,"fitn")
# Out:
# (0.990025f0, 1.0050005f0)
# "2025-09-09_23-05-42.mp4"

# %%
slice1 = threeDC["fitn"][:,:,30,:,1]
# Out:
# 11×11×351 Array{Float32, 3}:
# [:, :, 1] =
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [:, :, 2] =
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
re_heatmap(slice1,1,351)
# Out:
# 3
# (0.9747014f0, 0.9966682f0)
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# No values found in any deme.
# ...

# %%
function av_by_dist(obj,gen)
    return [NaNMath.mean(obj[:,:,z,gen,:]) for z in 1:size(obj)[3]]
end
# Out:
# av_by_dist (generic function with 1 method)

# %%
av_by_dist(threeDC["fitn"],N_GENS)
# Out:
# 50-element Vector{Float32}:
#  0.9975651
#  0.99790066
#  0.9979307
#  0.9979156
#  0.9978246
#  0.9977967
#  0.9976886
#  0.99766904
#  0.9975397
#  0.9974406
#  ⋮
#  0.99046874
#  0.9900642
#  0.98966914
#  0.989117
#  0.9886709
#  0.9881503
#  0.9876706
#  0.987041
#  0.9862547

# %%
Plots.plot(av_by_dist(threeDC["fitn"],N_GENS),xlabel="Distance from start",label="Mean deme-average fitness")
