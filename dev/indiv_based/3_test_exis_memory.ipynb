# %%
include("../../resk.jl")
#include("../../reskplots.jl")
# Out:
# RESK successfully loaded.
# analyse (generic function with 1 method)

# %%
Random.seed!(1234)
A = rangeexp_1d_inf()
analyse(A) # 0.99511963f0
# Out:
# 0.99511963f0
