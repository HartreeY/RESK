# %%
using Distributed
n_re = 30
addprocs(n_re)
@everywhere include("../../resk2.jl")
# Out:
#       From worker 5:	RESK successfully loaded.
#       From worker 2:	RESK successfully loaded.
#       From worker 23:	RESK successfully loaded.
#       From worker 22:	RESK successfully loaded.
#       From worker 11:	RESK successfully loaded.
#       From worker 16:	RESK successfully loaded.
#       From worker 13:	RESK successfully loaded.
#       From worker 20:	RESK successfully loaded.
#       From worker 19:	RESK successfully loaded.
#       From worker 31:	RESK successfully loaded.
#       From worker 29:	RESK successfully loaded.
#       From worker 6:	RESK successfully loaded.
#       From worker 12:	RESK successfully loaded.
#       From worker 15:	RESK successfully loaded.
#       From worker 24:	RESK successfully loaded.
#       From worker 25:	RESK successfully loaded.
#       From worker 3:	RESK successfully loaded.
#       From worker 27:	RESK successfully loaded.
#       From worker 21:	RESK successfully loaded.
#       From worker 9:	RESK successfully loaded.
#       From worker 4:	RESK successfully loaded.
#       From worker 8:	RESK successfully loaded.
#       From worker 26:	RESK successfully loaded.
#       From worker 28:	RESK successfully loaded.
#       From worker 30:	RESK successfully loaded.
#       From worker 7:	RESK successfully loaded.
#       From worker 10:	RESK successfully loaded.
#       From worker 17:	RESK successfully loaded.
#       From worker 14:	RESK successfully loaded.
#       From worker 18:	RESK successfully loaded.
# RESK successfully loaded.

# %%
A = rangeexp_1d_inf(100,300,1;x_max_burnin=5,x_max_exp=500,data_to_generate="GPlFl",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
n_segr_regions=20,weightfitn=false,condsel=true,fixed_mate=true,premutate=true,SS=true,verbose=false)
# Out:
# OrderedDict{String, Any} with 4 entries:
#   "stats" => WorldStats("2025-08-06_02-47-21", (500,), 100, 2.0, 20, [0.005, 0.…
#   "gt"    => Array{Array{Float32}}[[[1.005, 0.995, 1.0, 1.005, 1.00497, 0.995, …
#   "fitn"  => Float32[1.0 0.999753 … 0.957411 0.954822; 1.0 0.999735 … 0.959595 …
#   "pops"  => Float32[87.0; 69.0; … ; NaN; NaN;;]

# %%
out_show(A["fitn"])

# %%
Af = dropdims(A["fitn"]; dims=3)
Aff=mean(Af,dims=3)
# Out:
# 500×401×1 Array{Float32, 3}:
# [:, :, 1] =
#    1.0    0.999604    0.999163  …    0.957198    0.957272    0.957729
#    1.0    0.999546    0.99916        0.959658    0.959323    0.960309
#    1.0    0.999586    0.99921        0.963233    0.9632      0.963406
#    1.0    0.99964     0.999253       0.962576    0.962783    0.962349
#    1.0    0.999589    0.999175       0.960824    0.961089    0.961158
#  NaN    NaN         NaN         …    0.961034    0.96095     0.961761
#  NaN    NaN         NaN              0.962277    0.962194    0.962061
#  NaN    NaN         NaN              0.957634    0.958447    0.957582
#  NaN    NaN         NaN              0.953846    0.953875    0.954108
#  NaN    NaN         NaN              0.950619    0.950577    0.951093
#    ⋮                            ⋱                            ⋮
#  NaN    NaN         NaN            NaN         NaN         NaN
#  NaN    NaN         NaN            NaN         NaN         NaN
#  NaN    NaN         NaN            NaN         NaN         NaN
#  NaN    NaN         NaN            NaN         NaN         NaN
#  NaN    NaN         NaN         …  NaN         NaN         NaN
#  NaN    NaN         NaN            NaN         NaN         NaN
#  NaN    NaN         NaN            NaN         NaN         NaN
#  NaN    NaN         NaN            NaN         NaN         NaN
#  NaN    NaN         NaN            NaN         NaN         NaN

# %%
out_show(Aff)

# %%
Aff = dropdims(Aff; dims=3)
using Plots
heatmap(Aff,clim=(0,1.5))
