# %%
include("../../resk.jl")
include("../../reskplots.jl")
# Out:
# RESK successfully loaded.
# RESKPlots successfully loaded.

# %%
A = rangeexp_ray(0,1000,1;x_max_burnin=5,x_max_exp=500,data_to_generate="Fl",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
weightfitn=false,condsel=true,fixed_mate=true,SS=true)

# %%
re_heatmap(A,"fitn")
# Out:
# 2
# (0.98002976f0, 1.0f0)
# ┌ Info: Saved animation to C:\Users\LOCAL_~1\AppData\Local\Temp\jl_Ep2NGB29GF.gif
# └ @ Plots C:\Users\local_axjynym\.julia\packages\Plots\Ec1L1\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\LOCAL_~1\\AppData\\Local\\Temp\\jl_Ep2NGB29GF.gif")
