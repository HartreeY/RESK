# %%
include("../../resk.jl")
include("../../reskplots.jl")
# Out:
# RESK successfully loaded.
# RESKPlots successfully loaded.

# %%
# Testing the difference between "F", "FAl" and "FCl"
A = rangeexp_strip(20,20,1;x_max_burnin=5,y_max=7,x_max_exp=25,data_to_generate="F",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
weightfitn=false,condsel=true,fixed_mate=true,SS=true,prop_of_del_muts=0.9)
# min(t) = 22.7s
# Out:
# max_burnin (5, 7)
# startfill_range UnitRange{Int64}[1:5, 1:7]
# startfill_iter nothing
# Simulated in 22.7717403 s.
# OrderedDict{String, Any} with 2 entries:
#   "stats" => OrderedDict{String, Any}("name"=>"2025-09-10_00-03-26", "max"=>(25…
#   "fitn"  => Float32[0.999942 0.999937 … 0.999949 0.999951; 0.999868 0.999952 ……

# %%
# Testing the difference between "F", "FAl" and "FCl"
A = rangeexp_strip(20,20,1;x_max_burnin=5,y_max=7,x_max_exp=25,data_to_generate="FCl",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
weightfitn=false,condsel=true,fixed_mate=true,SS=true,prop_of_del_muts=0.9)
# min(t) = 22.7s
# Out:
# max_burnin (5, 7)
# startfill_range UnitRange{Int64}[1:5, 1:7]
# startfill_iter nothing
# Simulated in 22.6954972 s.
# OrderedDict{String, Any} with 5 entries:
#   "stats" => OrderedDict{String, Any}("name"=>"2025-09-10_00-07-58", "max"=>(25…
#   "fitn"  => Float32[0.999158 0.999692 … 0.999946 1.0; 0.999674 1.0 … 1.0 1.000…
#   "cAA"   => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "cAa"   => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "caa"   => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…

# %%
# Testing the difference between "F", "FAl" and "FCl"
A = rangeexp_strip(20,20,1;x_max_burnin=5,y_max=7,x_max_exp=25,data_to_generate="FAl",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
weightfitn=false,condsel=true,fixed_mate=true,SS=true,prop_of_del_muts=0.9)
# min(t) = 21.8s
# Out:
# max_burnin (5, 7)
# startfill_range UnitRange{Int64}[1:5, 1:7]
# startfill_iter nothing
# Simulated in 22.8471635 s.
# OrderedDict{String, Any} with 5 entries:
#   "stats" => OrderedDict{String, Any}("name"=>"2025-09-10_00-16-06", "max"=>(25…
#   "fitn"  => Float32[0.999491 0.999844 … 1.0 0.999903; 0.999632 0.999042 … 1.0 …
#   "AA"    => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "Aa"    => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "aa"    => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…

# %% [markdown]
# => The time does not depend on the output types

# %%
re_heatmap(A,"Aa")
# Out:
# 3
# (0.0f0, 0.288f0)
# No values found in any deme.
# ┌ Info: Saved animation to C:\Users\LOCAL_~1\AppData\Local\Temp\jl_XAHSZaZGjm.gif
# └ @ Plots C:\Users\local_axjynym\.julia\packages\Plots\Ec1L1\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\LOCAL_~1\\AppData\\Local\\Temp\\jl_XAHSZaZGjm.gif")

# %%
re_heatmap(A["Aa"])
# Out:
# 3
# (0.0f0, 0.288f0)
# No values found in any deme.
# ┌ Info: Saved animation to C:\Users\LOCAL_~1\AppData\Local\Temp\jl_xALqDO7wNY.gif
# └ @ Plots C:\Users\local_axjynym\.julia\packages\Plots\Ec1L1\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\LOCAL_~1\\AppData\\Local\\Temp\\jl_xALqDO7wNY.gif")

# %% [markdown]
# => Generated successfully, and the graphs are the same
