# %%
include("../../resk.jl")
include("../../reskplots.jl")
# Out:
# RESK successfully loaded.
# RESKPlots successfully loaded.

# %%
# Sim to test the sectors
A = rangeexp_cylinder(100,150,1;z_max_burnin=2,z_max_exp=20,r_max=15,data_to_generate="Fl",capacity=100,prolif_rate=2,mut_rate=0.05,migr_rate=0.05,sel_coef=0.005,
weightfitn=false,condsel=true,fixed_mate=true,SS=true,prop_of_del_muts=0.9)
# Waiting from RAIDEN
# Out:
# max_burnin (NaN, NaN, 3)
# startfill_range UnitRange{Int64}[6:26, 6:26, 1:3]
# startfill_iter nothing
# Simulated in 432.8066468 s.
# OrderedDict{String, Any} with 2 entries:
#   "stats" => OrderedDict{String, Any}("name"=>"2025-09-16_16-37-58", "max"=>(31…
#   "fitn"  => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…

# %%
threeDC = deserialize("../paperdata/cyltest1.re")
# Out:
# OrderedDict{String, Any} with 2 entries:
#   "stats" => OrderedDict{String, Any}("name"=>"2025-09-16_16-50-43", "max"=>(31…
#   "fitn"  => Float32[NaN NaN … NaN NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…

# %%
re_heatstack(threeDC,"fitn")
# Out:
# (0.9801495f0, 1.010025f0)
# "2025-09-16_18-21-08.mp4"
