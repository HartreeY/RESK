# %%
include("../resk.jl")
include("../reskplots.jl")
# Out:
# RESK successfully loaded.
# RESKPlots successfully loaded.

# %%
test_fitn_frontav = average_front(test,"Aa")
Plots.plot(test_fitn_frontav,xlabel="Generation",label="Mean front fitness")

# %%
test_fitn_av = average_all(test,"Aasel")
Plots.plot(test_fitn_av,xlabel="Generation",label="Mean front fitness")

# %%
test2 = rangeexp_strip(40,160,1;data_to_generate="MC",y_max=5,x_max_exp=40,bottleneck=NaN)
# Out:
# Dict{String, Any} with 9 entries:
#   "pops"  => Any[]
#   "cAa"   => Float32[NaN NaN … 0.0 NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "fitn"  => Any[]
#   "AA"    => Float32[NaN NaN … 0.0 NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "Aa"    => Float32[NaN NaN … 0.0 NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "stats" => Dict{String, Any}("capacity"=>20, "wlddim"=>2, "max_burnin"=>(5, 5…
#   "aa"    => Float32[NaN NaN … 1000.0 NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN…
#   ""   => Float32[NaN NaN … 0.0 NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN Na…
#   "caa"   => Float32[NaN NaN … 20.0 NaN; NaN NaN … NaN NaN; … ; NaN NaN … NaN N…

# %%
test_fitn_frontav = average_front(test2,"aa")
Plots.plot(test_fitn_frontav,xlabel="Generation",label="Mean front fitness")

# %%
test_fitn_av = average_all(test2,"Aa")
Plots.plot(test_fitn_av,xlabel="Generation",label="Mean front fitness")

# %%
re_heatmap(test2,"Aa")
# Out:
# (0.0f0, 94.318184f0)
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_WtudwVg3EP.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_WtudwVg3EP.gif")

# %%
re_heatmap(test,"Aa")
# Out:
# (0.0f0, 98.818184f0)
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_IvCfq34LcX.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_IvCfq34LcX.gif")

# %%
fill(a,5)
# Out:
# 5-element Vector{Matrix{Array{Array{Bool}}}}:
#  [#undef #undef #undef #undef; #undef #undef #undef #undef; #undef #undef #undef #undef]
#  [#undef #undef #undef #undef; #undef #undef #undef #undef; #undef #undef #undef #undef]
#  [#undef #undef #undef #undef; #undef #undef #undef #undef; #undef #undef #undef #undef]
#  [#undef #undef #undef #undef; #undef #undef #undef #undef; #undef #undef #undef #undef]
#  [#undef #undef #undef #undef; #undef #undef #undef #undef; #undef #undef #undef #undef]

# %%
re_heatmap(test["cAa"][:,:,1,:,1],30,150)
# Out:
# (0.0f0, 22.0f0)
# ┌ Info: Saved animation to C:\Users\Hartree\AppData\Local\Temp\jl_sVGlWlKrED.gif
# └ @ Plots C:\Users\Hartree\.julia\packages\Plots\ju9dp\src\animation.jl:156
# Plots.AnimatedGif("C:\\Users\\Hartree\\AppData\\Local\\Temp\\jl_sVGlWlKrED.gif")

# %%
function af_A(re,deme,locus,gen=re["stats"]["n_gens"],re_index=1)
    return (2*re["cAA"][deme...,locus,gen,re_index]+re["cAa"][deme...,locus,gen,re_index])/re["stats"]["n_loci"]
end

function af_a(re,deme,locus,gen=re["stats"]["n_gens"],re_index=1)
    return (2*re["caa"][deme...,locus,gen,re_index]+re["cAa"][deme...,locus,gen,re_index])/re["stats"]["n_loci"]
end
# Out:
# af_a (generic function with 3 methods)

# %%
Plots.heatmap(test["caa"][:,:,1,150,1]')

# %%
Plots.heatmap(test["cAa"][:,:,1,150,1]')

# %%
Plots.heatmap(test["cAA"][:,:,1,150,1]')

# %% [markdown]
# ---

# %%
A = deserialize("data/hoho.re")
# Out:
# UndefVarError: `deserialize` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ d:\Coding\Genetics\RESK\study\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X32sZmlsZQ==.jl:1

# %%
Plots.heatmap(A["fitn"][:,:,1,2]')

# %%
#(2*re["cAA"][1,1,1,70,1]+re["cAa"][deme...,locus,gen,re_index])/re["stats"]["n_loci"]
mean(af_A(test,(1,1),1:test["stats"]["n_loci"]))
# Out:
# 0.0025469998f0

# %%
function twopq(re,deme,locus::Int,gen=re["stats"]["n_gens"],re_index=1)
    a = af_A(re,deme,locus,gen,re_index)
    return a*(1-a)*2
end

function twopq(re,deme,loci::Array,gen=re["stats"]["n_gens"],re_index=1)
    return mean([af_A(re,deme,l,gen,re_index)*(1-af_A(re,deme,l,gen,re_index))*2 for l in loci])
end

function twopq(re,deme,loci::UnitRange=1:test["stats"]["n_loci"],gen=re["stats"]["n_gens"],re_index=1)
    return mean([af_A(re,deme,l,gen,re_index)*(1-af_A(re,deme,l,gen,re_index))*2 for l in loci])
end

H_11 = twopq(test,(1,1))
# Out:
# 0.002195376f0

# %%
test["caa"][10,5,1,150,1]
# Out:
# 11.0f0

# %%
H_end = mean([twopq(test,(10,5),i) for i in 1:test["stats"]["n_loci"]])
# Out:
# 0.0030967898f0

# %%
bois = [(1,1),(10,5)]
